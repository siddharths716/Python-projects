# %%
board = [" "," "," "," "," "," "," "," "," "," "]

# %%
def display_board(board):
    print(board[7] +"|" + board[8] +"|" +board[9] )
    print("------")
    print(board[4] +"|" + board[5] +"|" +board[6] )
    print("------")
    print(board[1] +"|" + board[2] +"|" +board[3] )

# %%
temp = True
def check(board):
    if (board[7]==board[5]==board[3]=='X') or (board[7]==board[4]==board[1]=='X') or (board[8]==board[5]==board[2]=='X') or (board[9]==board[6]==board[3]=='X') or (board[9]==board[5]==board[1]=='X') or (board[7]==board[8]==board[9]=='X') or (board[4]==board[5]==board[6]=='X') or (board[1]==board[2]==board[3]=='X'):
        print("player X has won")
        temp = False
        exit()
    elif (board[7]==board[5]==board[3]=='O') or (board[7]==board[4]==board[1]=='O') or (board[8]==board[5]==board[2]=='O') or (board[9]==board[6]==board[3]=='O') or (board[9]==board[5]==board[1]=='O') or (board[7]==board[8]==board[9]=='O') or (board[4]==board[5]==board[6]=='O') or (board[1]==board[2]==board[3]=='O'):
        print("player O has won")
        temp = False
        exit()

# %%
from IPython.display import clear_output
in1 = 0
in2 = 0
while(in1!='X' or in1!='O'):
    in1 = input("Player 1: Do you want to be X or O ")
    if in1 == 'X':
        in2 = 'O'
        break
    elif in1=='O':
        in2 = 'X'
        break


display_board(board)
a = int(input("enter the location you want to enter"))
board[a] = 'X'
print('\n'*100)
display_board(board)
check(board)
a = int(input("enter the location you want to enter"))
board[a] = 'O'
print('\n'*100)
display_board(board)
check(board)
a = int(input("enter the location you want to enter"))
board[a] = 'X'
print('\n'*100)
display_board(board)
check(board)
a = int(input("enter the location you want to enter"))
board[a] = 'O'
print('\n'*100)
display_board(board)
check(board)
a = int(input("enter the location you want to enter"))
board[a] = 'X'
print('\n'*100)
display_board(board)
check(board)
a = int(input("enter the location you want to enter"))
board[a] = 'O'
print('\n'*100)
display_board(board)
check(board)
a = int(input("enter the location you want to enter"))
board[a] = 'X'
print('\n'*100)
display_board(board)
check(board)
a = int(input("enter the location you want to enter"))
board[a] = 'O'
print('\n'*100)
display_board(board)
check(board)
a = int(input("enter the location you want to enter"))
board[a] = 'X'
print('\n'*100)
display_board(board)
check(board)
if temp == True:
    print("its a tie")
# Out:
# Player 1: Do you want to be X or O X
#  | |
# ------
#  | |
# ------
#  | |
# enter the location you want to enter4
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  | |
# ------
# X| |
# ------
#  | |
# enter the location you want to enter6
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  | |
# ------
# X| |O
# ------
#  | |
# enter the location you want to enter5
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  | |
# ------
# X|X|O
# ------
#  | |
# enter the location you want to enter8
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
